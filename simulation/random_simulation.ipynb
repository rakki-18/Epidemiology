# %%
import pandas as pd
import sys
import random

# %%
sys.path.append('../')

# %%
# From random_strategy import vaccination_strategy
from utils import SIR, run
from vaccination_strategy.random_strategy import vaccination_strategy

# %%
metadata = pd.read_csv('../metadata.csv', sep='\t', lineterminator='\n', names=['ID', 'Class', 'Sex'])
df = pd.read_csv('../contact_network.csv')

# %%
model = SIR(
    metadata=metadata,
    df=df
)

# %%
vaccinated = vaccination_strategy(model)

# %%
run(model,vaccinated,5)
# Out:
# At day 0
# Number of susceptible:  230
# Number of infected:  12
# Number of recovered:  0
# Number of deceased:  0
# After Day  1
# Number of susceptible:  192
# Number of infected:  45
# Number of recovered:  3
# Number of deceased:  2
# After Day  2
# Number of susceptible:  118
# Number of infected:  101
# Number of recovered:  16
# Number of deceased:  7
# After Day  3
# Number of susceptible:  42
# Number of infected:  140
# Number of recovered:  46
# Number of deceased:  14
# After Day  4
# Number of susceptible:  12
# Number of infected:  122
# Number of recovered:  88
# Number of deceased:  20
# After Day  5
# Number of susceptible:  3
# Number of infected:  60
# Number of recovered:  155
# Number of deceased:  24
# After Day  6
# Number of susceptible:  3
# Number of infected:  40
# Number of recovered:  173
# Number of deceased:  26
# After Day  7
# Number of susceptible:  3
# Number of infected:  27
# Number of recovered:  185
# Number of deceased:  27
# After Day  8
# Number of susceptible:  3
# Number of infected:  19
# Number of recovered:  193
# Number of deceased:  27
# After Day  9
# Number of susceptible:  3
# Number of infected:  14
# Number of recovered:  198
# Number of deceased:  27
# After Day  10
# Number of susceptible:  3
# Number of infected:  10
# Number of recovered:  202
# Number of deceased:  27
# After Day  11
# Number of susceptible:  3
# Number of infected:  7
# Number of recovered:  205
# Number of deceased:  27
# After Day  12
# Number of susceptible:  3
# Number of infected:  5
# Number of recovered:  207
# Number of deceased:  27
# After Day  13
# Number of susceptible:  3
# Number of infected:  4
# Number of recovered:  208
# Number of deceased:  27
# After Day  14
# Number of susceptible:  3
# Number of infected:  3
# Number of recovered:  209
# Number of deceased:  27
# After Day  15
# Number of susceptible:  3
# Number of infected:  3
# Number of recovered:  209
# Number of deceased:  27
# After Day  16
# Number of susceptible:  3
# Number of infected:  3
# Number of recovered:  209
# Number of deceased:  27
# After Day  17
# Number of susceptible:  3
# Number of infected:  3
# Number of recovered:  209
# Number of deceased:  27
# After Day  18
# Number of susceptible:  3
# Number of infected:  3
# Number of recovered:  209
# Number of deceased:  27
# After Day  19
# Number of susceptible:  3
# Number of infected:  3
# Number of recovered:  209
# Number of deceased:  27
# After Day  20
# Number of susceptible:  3
# Number of infected:  3
# Number of recovered:  209
# Number of deceased:  27
# After Day  21
# Number of susceptible:  3
# Number of infected:  3
# Number of recovered:  209
# Number of deceased:  27
# After Day  22
# Number of susceptible:  3
# Number of infected:  3
# Number of recovered:  209
# Number of deceased:  27
# After Day  23
# Number of susceptible:  3
# Number of infected:  3
# Number of recovered:  209
# Number of deceased:  27
# After Day  24
# Number of susceptible:  3
# Number of infected:  3
# Number of recovered:  209
# Number of deceased:  27
# After Day  25
# Number of susceptible:  3
# Number of infected:  3
# Number of recovered:  209
# Number of deceased:  27
# After Day  26
# Number of susceptible:  2
# Number of infected:  4
# Number of recovered:  209
# Number of deceased:  27
# After Day  27
# Number of susceptible:  2
# Number of infected:  3
# Number of recovered:  210
# Number of deceased:  27
# After Day  28
# Number of susceptible:  2
# Number of infected:  3
# Number of recovered:  210
# Number of deceased:  27
# After Day  29
# Number of susceptible:  2
# Number of infected:  3
# Number of recovered:  210
# Number of deceased:  27
# After Day  30
# Number of susceptible:  2
# Number of infected:  3
# Number of recovered:  210
# Number of deceased:  27
# {'metrics': {'total_deaths': 27, 'peak_infections': 140}}
