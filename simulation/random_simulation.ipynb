# %%
import pandas as pd
import sys
import random

# %%
sys.path.append('../')

# %%
# from random_strategy import vaccination_strategy
from utils import SIR, run
from vaccination_strategy.random_strategy import vaccination_strategy

# %%
model = SIR()
vaccinated = vaccination_strategy(model)
run(model,vaccinated)
# Out:
# At day 0
# Number of susceptible:  390
# Number of infected:  8
# Number of recovered:  99
# After Day  1
# Number of susceptible:  373
# Number of infected:  23
# Number of recovered:  101
# After Day  2
# Number of susceptible:  333
# Number of infected:  57
# Number of recovered:  107
# After Day  3
# Number of susceptible:  279
# Number of infected:  94
# Number of recovered:  124
# After Day  4
# Number of susceptible:  227
# Number of infected:  118
# Number of recovered:  152
# After Day  5
# Number of susceptible:  213
# Number of infected:  97
# Number of recovered:  187
# After Day  6
# Number of susceptible:  211
# Number of infected:  70
# Number of recovered:  216
# After Day  7
# Number of susceptible:  211
# Number of infected:  49
# Number of recovered:  237
# After Day  8
# Number of susceptible:  210
# Number of infected:  36
# Number of recovered:  251
# After Day  9
# Number of susceptible:  210
# Number of infected:  26
# Number of recovered:  261
# After Day  10
# Number of susceptible:  209
# Number of infected:  20
# Number of recovered:  268
# After Day  11
# Number of susceptible:  209
# Number of infected:  14
# Number of recovered:  274
# After Day  12
# Number of susceptible:  209
# Number of infected:  10
# Number of recovered:  278
# After Day  13
# Number of susceptible:  209
# Number of infected:  7
# Number of recovered:  281
# After Day  14
# Number of susceptible:  209
# Number of infected:  5
# Number of recovered:  283
# After Day  15
# Number of susceptible:  209
# Number of infected:  4
# Number of recovered:  284
# After Day  16
# Number of susceptible:  209
# Number of infected:  3
# Number of recovered:  285
# After Day  17
# Number of susceptible:  209
# Number of infected:  3
# Number of recovered:  285
# After Day  18
# Number of susceptible:  209
# Number of infected:  3
# Number of recovered:  285
# After Day  19
# Number of susceptible:  209
# Number of infected:  3
# Number of recovered:  285
# After Day  20
# Number of susceptible:  209
# Number of infected:  3
# Number of recovered:  285
# After Day  21
# Number of susceptible:  209
# Number of infected:  3
# Number of recovered:  285
# After Day  22
# Number of susceptible:  209
# Number of infected:  3
# Number of recovered:  285
# After Day  23
# Number of susceptible:  209
# Number of infected:  3
# Number of recovered:  285
# After Day  24
# Number of susceptible:  209
# Number of infected:  3
# Number of recovered:  285
# After Day  25
# Number of susceptible:  209
# Number of infected:  3
# Number of recovered:  285
# After Day  26
# Number of susceptible:  209
# Number of infected:  3
# Number of recovered:  285
# After Day  27
# Number of susceptible:  209
# Number of infected:  3
# Number of recovered:  285
# After Day  28
# Number of susceptible:  209
# Number of infected:  3
# Number of recovered:  285
# After Day  29
# Number of susceptible:  209
# Number of infected:  3
# Number of recovered:  285
# After Day  30
# Number of susceptible:  208
# Number of infected:  4
# Number of recovered:  285
