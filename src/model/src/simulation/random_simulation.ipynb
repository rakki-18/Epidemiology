# %%
import pandas as pd
import sys

# %%
sys.path.append('../')

# %%
# From random_strategy import vaccination_strategy
from utils import SIR, run
from vaccination_strategy.random_strategy import random_vaccination_strategy

# %%
metadata = pd.read_csv('../data/generation/metadata.csv')
# Have to remove the first row as it is headings duplicated
metadata = metadata.iloc[1:, : ]
df = pd.read_csv('../data/generation/contact_network.csv')

# %%
df.describe()
# Out:
#           Unnamed: 0      timestamp             p1             p2
# count  207426.000000  207426.000000  207426.000000  207426.000000
# mean   103712.500000      61.854271     192.709950     192.381804
# std     59878.872806      34.638542     110.991228     110.865794
# min         0.000000       1.000000       0.000000       0.000000
# 25%     51856.250000      31.000000      96.000000      95.000000
# 50%    103712.500000      63.000000     192.000000     192.000000
# 75%    155568.750000      91.000000     288.000000     287.000000
# max    207425.000000     120.000000     386.000000     386.000000

# %%
metadata.head()
# Out:
#    id  age  apartment  home  family  office  school
# 1   1   32          0    -1       0       6      -1
# 2   2   35          0    -1       1      -1      -1
# 3   3   65          0    -1       1      -1      -1
# 4   4   48          0    -1       2      -1      -1
# 5   5   44          0    -1       2       3      -1

# %%
model = SIR(
    metadata=metadata,
    df=df
)

# %%
vaccinated = random_vaccination_strategy(model)

# %%
run(model,vaccinated,5)
# Out:
# At day 0
# Number of susceptible:  356
# Number of infected:  30
# Number of recovered:  0
# Number of deceased:  0
# After 1 day(s)
# Number of susceptible:  334
# Number of infected:  51
# Number of recovered:  1
# Number of deceased:  0
# After 2 day(s)
# Number of susceptible:  309
# Number of infected:  75
# Number of recovered:  2
# Number of deceased:  0
# After 3 day(s)
# Number of susceptible:  283
# Number of infected:  99
# Number of recovered:  4
# Number of deceased:  0
# After 4 day(s)
# Number of susceptible:  259
# Number of infected:  118
# Number of recovered:  6
# Number of deceased:  3
# After 5 day(s)
# Number of susceptible:  192
# Number of infected:  110
# Number of recovered:  81
# Number of deceased:  3
# After 6 day(s)
# Number of susceptible:  179
# Number of infected:  118
# Number of recovered:  85
# Number of deceased:  4
# After 7 day(s)
# Number of susceptible:  161
# Number of infected:  133
# Number of recovered:  88
# Number of deceased:  4
# After 8 day(s)
# Number of susceptible:  143
# Number of infected:  145
# Number of recovered:  94
# Number of deceased:  4
# After 9 day(s)
# Number of susceptible:  123
# Number of infected:  159
# Number of recovered:  99
# Number of deceased:  5
# After 10 day(s)
# Number of susceptible:  116
# Number of infected:  159
# Number of recovered:  105
# Number of deceased:  6
# After 11 day(s)
# Number of susceptible:  107
# Number of infected:  167
# Number of recovered:  106
# Number of deceased:  6
# After 12 day(s)
# Number of susceptible:  96
# Number of infected:  171
# Number of recovered:  112
# Number of deceased:  7
# After 13 day(s)
# Number of susceptible:  87
# Number of infected:  173
# Number of recovered:  117
# Number of deceased:  9
# After 14 day(s)
# Number of susceptible:  77
# Number of infected:  178
# Number of recovered:  121
# Number of deceased:  10
# After 15 day(s)
# Number of susceptible:  68
# Number of infected:  180
# Number of recovered:  125
# Number of deceased:  13
# After 16 day(s)
# Number of susceptible:  60
# Number of infected:  182
# Number of recovered:  130
# Number of deceased:  14
# After 17 day(s)
# Number of susceptible:  54
# Number of infected:  181
# Number of recovered:  137
# Number of deceased:  14
# After 18 day(s)
# Number of susceptible:  52
# Number of infected:  174
# Number of recovered:  143
# Number of deceased:  17
# After 19 day(s)
# Number of susceptible:  51
# Number of infected:  169
# Number of recovered:  149
# Number of deceased:  17
# After 20 day(s)
# Number of susceptible:  45
# Number of infected:  167
# Number of recovered:  157
# Number of deceased:  17
# After 21 day(s)
# Number of susceptible:  43
# Number of infected:  161
# Number of recovered:  165
# Number of deceased:  17
# After 22 day(s)
# Number of susceptible:  39
# Number of infected:  162
# Number of recovered:  168
# Number of deceased:  17
# After 23 day(s)
# Number of susceptible:  39
# Number of infected:  156
# Number of recovered:  173
# Number of deceased:  18
# After 24 day(s)
# Number of susceptible:  35
# Number of infected:  155
# Number of recovered:  176
# Number of deceased:  20
# After 25 day(s)
# Number of susceptible:  31
# Number of infected:  157
# Number of recovered:  177
# Number of deceased:  21
# After 26 day(s)
# Number of susceptible:  31
# Number of infected:  154
# Number of recovered:  178
# Number of deceased:  23
# After 27 day(s)
# Number of susceptible:  26
# Number of infected:  155
# Number of recovered:  180
# Number of deceased:  25
# After 28 day(s)
# Number of susceptible:  26
# Number of infected:  152
# Number of recovered:  182
# Number of deceased:  26
# After 29 day(s)
# Number of susceptible:  25
# Number of infected:  144
# Number of recovered:  190
# Number of deceased:  27
# After 30 day(s)
# Number of susceptible:  21
# Number of infected:  146
# Number of recovered:  192
# Number of deceased:  27
# After 31 day(s)
# Number of susceptible:  21
# Number of infected:  142
# Number of recovered:  196
# Number of deceased:  27
# {'metrics': {'total_deaths': 27, 'peak_infections': 182},
#  'stats': {'susceptible': [356,
#    334,
#    309,
#    283,
#    259,
#    236,
#    179,
#    161,
#    143,
#    123,
#    116,
#    107,
#    96,
#    87,
#    77,
#    68,
#    60,
#    54,
#    52,
#    51,
#    45,
#    43,
#    39,
#    39,
#    35,
#    31,
#    31,
#    26,
#    26,
#    25,
#    21,
#    21],
#   'infected': [30,
#    51,
#    75,
#    99,
#    118,
#    141,
#    118,
#    133,
#    145,
#    159,
#    159,
#    167,
#    171,
#    173,
#    178,
#    180,
#    182,
#    181,
#    174,
#    169,
#    167,
#    161,
#    162,
#    156,
#    155,
#    157,
#    154,
#    155,
#    152,
#    144,
#    146,
#    142],
#   'recovered': [0,
#    1,
#    2,
#    4,
#    6,
#    6,
#    85,
#    88,
#    94,
#    99,
#    105,
#    106,
#    112,
#    117,
#    121,
#    125,
#    130,
#    137,
#    143,
#    149,
#    157,
#    165,
#    168,
#    173,
#    176,
#    177,
#    178,
#    180,
#    182,
#    190,
#    192,
#    196],
#   'deceased': [0,
#    0,
#    0,
#    0,
#    3,
#    3,
#    4,
#    4,
#    4,
#    5,
#    6,
#    6,
#    7,
#    9,
#    10,
#    13,
#    14,
#    14,
#    17,
#    17,
#    17,
#    17,
#    17,
#    18,
#    20,
#    21,
#    23,
#    25,
#    26,
#    27,
#    27,
#    27]}}
