# %%
import pandas as pd
import sys

# %%
sys.path.append('../')

# %%
# From random_strategy import vaccination_strategy
from utils import SIR, run
from vaccination_strategy.random_strategy import random_vaccination_strategy

# %%
metadata = pd.read_csv('../data/generation/metadata.csv')
# Have to remove the first row as it is headings duplicated
metadata = metadata.iloc[1:, : ]
df = pd.read_csv('../data/generation/contact_network.csv')

# %%
df.describe()
# Out:
#         Unnamed: 0    timestamp            p1            p2
# count  52996.00000  52996.00000  52996.000000  52996.000000
# mean   26497.50000     61.28338     91.067231     91.676598
# std    15298.77177     34.67141     53.210174     53.306808
# min        0.00000      1.00000      0.000000      0.000000
# 25%    13248.75000     31.00000     45.000000     46.000000
# 50%    26497.50000     63.00000     91.000000     92.000000
# 75%    39746.25000     91.00000    136.000000    137.000000
# max    52995.00000    120.00000    187.000000    187.000000

# %%
metadata.head()
# Out:
#    id  age  apartment  home  family  office  school
# 1   1    3          0    -1       0      -1       0
# 2   2    3          0    -1       0      -1       0
# 3   3    8          0    -1       0      -1       1
# 4   4   68          0    -1       0      -1      -1
# 5   5   31          0    -1       1      -1      -1

# %%
model = SIR(
    metadata=metadata,
    df=df
)

# %%
vaccinated = random_vaccination_strategy(model)

# %%
run(model,vaccinated,5)
# Out:
# At day 0
# Number of susceptible:  157
# Number of infected:  30
# Number of recovered:  0
# Number of deceased:  0
# After 1 day(s)
# Number of susceptible:  148
# Number of infected:  39
# Number of recovered:  0
# Number of deceased:  0
# After 2 day(s)
# Number of susceptible:  139
# Number of infected:  47
# Number of recovered:  1
# Number of deceased:  0
# After 3 day(s)
# Number of susceptible:  126
# Number of infected:  59
# Number of recovered:  2
# Number of deceased:  0
# After 4 day(s)
# Number of susceptible:  113
# Number of infected:  68
# Number of recovered:  6
# Number of deceased:  0
# After 5 day(s)
# Number of susceptible:  76
# Number of infected:  68
# Number of recovered:  43
# Number of deceased:  0
# After 6 day(s)
# Number of susceptible:  73
# Number of infected:  68
# Number of recovered:  46
# Number of deceased:  0
# After 7 day(s)
# Number of susceptible:  69
# Number of infected:  70
# Number of recovered:  47
# Number of deceased:  1
# After 8 day(s)
# Number of susceptible:  66
# Number of infected:  69
# Number of recovered:  50
# Number of deceased:  2
# After 9 day(s)
# Number of susceptible:  57
# Number of infected:  77
# Number of recovered:  50
# Number of deceased:  3
# After 10 day(s)
# Number of susceptible:  53
# Number of infected:  77
# Number of recovered:  53
# Number of deceased:  4
# After 11 day(s)
# Number of susceptible:  51
# Number of infected:  74
# Number of recovered:  58
# Number of deceased:  4
# After 12 day(s)
# Number of susceptible:  48
# Number of infected:  73
# Number of recovered:  62
# Number of deceased:  4
# After 13 day(s)
# Number of susceptible:  44
# Number of infected:  76
# Number of recovered:  62
# Number of deceased:  5
# After 14 day(s)
# Number of susceptible:  39
# Number of infected:  79
# Number of recovered:  64
# Number of deceased:  5
# After 15 day(s)
# Number of susceptible:  34
# Number of infected:  82
# Number of recovered:  65
# Number of deceased:  6
# After 16 day(s)
# Number of susceptible:  27
# Number of infected:  85
# Number of recovered:  69
# Number of deceased:  6
# After 17 day(s)
# Number of susceptible:  24
# Number of infected:  87
# Number of recovered:  69
# Number of deceased:  7
# After 18 day(s)
# Number of susceptible:  18
# Number of infected:  90
# Number of recovered:  71
# Number of deceased:  8
# After 19 day(s)
# Number of susceptible:  15
# Number of infected:  90
# Number of recovered:  74
# Number of deceased:  8
# After 20 day(s)
# Number of susceptible:  15
# Number of infected:  88
# Number of recovered:  76
# Number of deceased:  8
# After 21 day(s)
# Number of susceptible:  15
# Number of infected:  81
# Number of recovered:  80
# Number of deceased:  11
# After 22 day(s)
# Number of susceptible:  14
# Number of infected:  82
# Number of recovered:  80
# Number of deceased:  11
# After 23 day(s)
# Number of susceptible:  12
# Number of infected:  82
# Number of recovered:  81
# Number of deceased:  12
# After 24 day(s)
# Number of susceptible:  10
# Number of infected:  83
# Number of recovered:  82
# Number of deceased:  12
# After 25 day(s)
# Number of susceptible:  9
# Number of infected:  83
# Number of recovered:  83
# Number of deceased:  12
# After 26 day(s)
# Number of susceptible:  7
# Number of infected:  82
# Number of recovered:  86
# Number of deceased:  12
# After 27 day(s)
# Number of susceptible:  7
# Number of infected:  79
# Number of recovered:  89
# Number of deceased:  12
# After 28 day(s)
# Number of susceptible:  6
# Number of infected:  76
# Number of recovered:  93
# Number of deceased:  12
# After 29 day(s)
# Number of susceptible:  6
# Number of infected:  73
# Number of recovered:  94
# Number of deceased:  14
# After 30 day(s)
# Number of susceptible:  6
# Number of infected:  68
# Number of recovered:  99
# Number of deceased:  14
# After 31 day(s)
# Number of susceptible:  6
# Number of infected:  67
# Number of recovered:  100
# Number of deceased:  14
# {'metrics': {'total_deaths': 14, 'peak_infections': 90},
#  'stats': {'susceptible': [157,
#    148,
#    139,
#    126,
#    113,
#    98,
#    73,
#    69,
#    66,
#    57,
#    53,
#    51,
#    48,
#    44,
#    39,
#    34,
#    27,
#    24,
#    18,
#    15,
#    15,
#    15,
#    14,
#    12,
#    10,
#    9,
#    7,
#    7,
#    6,
#    6,
#    6,
#    6],
#   'infected': [30,
#    39,
#    47,
#    59,
#    68,
#    83,
#    68,
#    70,
#    69,
#    77,
#    77,
#    74,
#    73,
#    76,
#    79,
#    82,
#    85,
#    87,
#    90,
#    90,
#    88,
#    81,
#    82,
#    82,
#    83,
#    83,
#    82,
#    79,
#    76,
#    73,
#    68,
#    67],
#   'recovered': [0,
#    0,
#    1,
#    2,
#    6,
#    6,
#    46,
#    47,
#    50,
#    50,
#    53,
#    58,
#    62,
#    62,
#    64,
#    65,
#    69,
#    69,
#    71,
#    74,
#    76,
#    80,
#    80,
#    81,
#    82,
#    83,
#    86,
#    89,
#    93,
#    94,
#    99,
#    100],
#   'deceased': [0,
#    0,
#    0,
#    0,
#    0,
#    0,
#    0,
#    1,
#    2,
#    3,
#    4,
#    4,
#    4,
#    5,
#    5,
#    6,
#    6,
#    7,
#    8,
#    8,
#    8,
#    11,
#    11,
#    12,
#    12,
#    12,
#    12,
#    12,
#    12,
#    14,
#    14,
#    14]}}
