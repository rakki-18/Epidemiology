# %%
import pandas as pd
import sys

# %%
sys.path.append('../')

# %%
# From random_strategy import vaccination_strategy
from utils import SIR, run
from vaccination_strategy.random_strategy import vaccination_strategy

# %%
metadata = pd.read_csv('../dataset/metadata.csv', sep='\t', lineterminator='\n', names=['ID', 'Class', 'Sex'])
df = pd.read_csv('../dataset/contact_network.csv')

# %%
df.head()
# Out:
#     Time  Person 1  Person 2 Class1  Class2
# 0  31220      1558      1567      3B     3B
# 1  31220      1560      1570      3B     3B
# 2  31220      1567      1574      3B     3B
# 3  31220      1632      1818      4B     4B
# 4  31220      1632      1866      4B     4B

# %%
model = SIR(
    metadata=metadata,
    df=df
)

# %%
vaccinated = vaccination_strategy(model)

# %%
run(model,vaccinated,5)
# Out:
# At day 0
# Number of susceptible:  230
# Number of infected:  12
# Number of recovered:  236
# Number of deceased:  53
# After Day  1
# Number of susceptible:  187
# Number of infected:  50
# Number of recovered:  236
# Number of deceased:  54
# After Day  2
# Number of susceptible:  127
# Number of infected:  91
# Number of recovered:  237
# Number of deceased:  55
# After Day  3
# Number of susceptible:  78
# Number of infected:  108
# Number of recovered:  237
# Number of deceased:  60
# After Day  4
# Number of susceptible:  14
# Number of infected:  133
# Number of recovered:  237
# Number of deceased:  66
# After Day  5
# Number of susceptible:  6
# Number of infected:  76
# Number of recovered:  238
# Number of deceased:  69
# After Day  6
# Number of susceptible:  6
# Number of infected:  52
# Number of recovered:  238
# Number of deceased:  71
# After Day  7
# Number of susceptible:  6
# Number of infected:  36
# Number of recovered:  240
# Number of deceased:  71
# After Day  8
# Number of susceptible:  6
# Number of infected:  25
# Number of recovered:  240
# Number of deceased:  71
# After Day  9
# Number of susceptible:  5
# Number of infected:  19
# Number of recovered:  240
# Number of deceased:  71
# After Day  10
# Number of susceptible:  5
# Number of infected:  14
# Number of recovered:  240
# Number of deceased:  71
# After Day  11
# Number of susceptible:  5
# Number of infected:  10
# Number of recovered:  240
# Number of deceased:  71
# After Day  12
# Number of susceptible:  5
# Number of infected:  7
# Number of recovered:  240
# Number of deceased:  71
# After Day  13
# Number of susceptible:  5
# Number of infected:  5
# Number of recovered:  240
# Number of deceased:  71
# After Day  14
# Number of susceptible:  5
# Number of infected:  4
# Number of recovered:  240
# Number of deceased:  71
# After Day  15
# Number of susceptible:  5
# Number of infected:  3
# Number of recovered:  240
# Number of deceased:  71
# After Day  16
# Number of susceptible:  5
# Number of infected:  3
# Number of recovered:  240
# Number of deceased:  71
# After Day  17
# Number of susceptible:  5
# Number of infected:  3
# Number of recovered:  240
# Number of deceased:  71
# After Day  18
# Number of susceptible:  4
# Number of infected:  4
# Number of recovered:  240
# Number of deceased:  71
# After Day  19
# Number of susceptible:  4
# Number of infected:  3
# Number of recovered:  240
# Number of deceased:  71
# After Day  20
# Number of susceptible:  4
# Number of infected:  3
# Number of recovered:  240
# Number of deceased:  71
# After Day  21
# Number of susceptible:  4
# Number of infected:  3
# Number of recovered:  240
# Number of deceased:  71
# After Day  22
# Number of susceptible:  4
# Number of infected:  3
# Number of recovered:  240
# Number of deceased:  71
# After Day  23
# Number of susceptible:  4
# Number of infected:  3
# Number of recovered:  240
# Number of deceased:  71
# After Day  24
# Number of susceptible:  4
# Number of infected:  3
# Number of recovered:  240
# Number of deceased:  71
# After Day  25
# Number of susceptible:  4
# Number of infected:  3
# Number of recovered:  240
# Number of deceased:  71
# After Day  26
# Number of susceptible:  4
# Number of infected:  3
# Number of recovered:  240
# Number of deceased:  71
# After Day  27
# Number of susceptible:  4
# Number of infected:  3
# Number of recovered:  240
# Number of deceased:  71
# After Day  28
# Number of susceptible:  4
# Number of infected:  3
# Number of recovered:  240
# Number of deceased:  71
# After Day  29
# Number of susceptible:  4
# Number of infected:  3
# Number of recovered:  240
# Number of deceased:  71
# After Day  30
# Number of susceptible:  4
# Number of infected:  3
# Number of recovered:  240
# Number of deceased:  71
# {'metrics': {'total_deaths': 71, 'peak_infections': 133}}
